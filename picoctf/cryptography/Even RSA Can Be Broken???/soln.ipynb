# %%
from Crypto.Util.number import *

# %%
n = 23919318781028756229010821621974594145763155500105808267999985713551492920778808174335200152884699963807723121663068481751632815427459405283827515691531854
e = 65537
ct = 6004946616456811489810415926305074872384715651093492149876439076578285377076987711918827342037539055610284976813069469741974549801721149979242042180206723

# %%
p = 11959659390514378114505410810987297072881577750052904133999992856775746460389404087167600076442349981903861560831534240875816407713729702641913757845765927
q = 23919318781028756229010821621974594145763155500105808267999985713551492920778808174335200152884699963807723121663068481751632815427459405283827515691531854
phi = (p - 1) * (q - 1)
d = inverse(e, phi)

# %%
m = pow(ct, d, n)
print(long_to_bytes(m).decode())
# Out:
# picoCTF{tw0_1$_pr!m305af7255}
